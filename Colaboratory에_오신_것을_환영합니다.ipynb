# %%
# !pip install konlpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 49.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.1/494.1 kB 18.1 MB/s eta 0:00:00
# ...

# %%
import csv
from konlpy.tag import Okt

f = open(r'data/ratings_train.txt', 'r', encoding='utf-8')
rdr = csv.reader(f, delimiter='\t')
rdw = list(rdr)
f.close()

# %%
twitter = Okt()
result = []

for line in rdw:
  malist = twitter.pos(line[1], norm=True, stem=True)
  r = []
  for word in malist:
    if not word[1] in ["Josa", "Eomi", "Punctuation"]:
      r.append(word[0])
  rl = (" ".join(r)).strip()
  result.append(rl)
  print(rl)
# Out:
# 한일 관계 대한 대통령 특별 담화 문
# 존경 하다 국민 여러분
# 독도 우리 땅 이다 그냥 우리 땅 아니다 40년 통한 역사 뚜렷하다 새기다 있다 역사 땅 이다 독도 일본 한반도 침탈 과정 가장 먼저 병탄 되어다 우리 땅 이다 일본 러일전쟁 중 전쟁 수행 목적 편입 점령 하다 땅 이다 러일전쟁 제국주의 일본 한국 대한 지배권 확보 하다 위해 일으키다 한반도 침략전쟁 이다
# 일본 러일전쟁 빌다 미로 우리 땅 군대 상륙 시키다 한반도 점령 하다 군대 동원 하다 궁 포위 황실 정부 협박 하다 한일의정서 강제 체결 토지 한 국민 징발 군사시설 설치 하다 우리 국토 일부 일방 적 군정 실시 나중 재정권 외교 권 박탈 하다 우리 주권 유린 하다
# 일본 이렇다 와중 독도 자국 영토 편입 망루 전선 가설 하다 전쟁 이용 하다 것 이다 그리고 한반도 대한 군사 적 점령 상태 계속 하다 국권 박탈 식민지 지배권 확보 하다
# 독도 대한 권리 주장 식민지 영토권 주장 하다 격
# 지금 일본 독도 대한 권리 주장 하다 것 제국주의 침략전쟁 의하다 점령 권리 나아가다 과거 식민지 영토권 주장 하다 것 이다 이 것 한국 완전하다 해방 독립 부정 하다 행위 이다 또한 과거 일본 저지르다 침략전쟁 학살 40년 간에 걸치다 수탈 고문 투옥 강제 징용 심지어 위안부 동원 하다 그 범죄 역사 대한 정당성 주장 하다 행위 이다 우리 결코 이르다 용납 하다 수 없다
# 우리 국민 독도 완전하다 주권 회복 상징 이다 야스쿠니신사 참배 역사 교과서 문제 더불다 과거 역사 대한 일본 인식 그리고 미래 한일 관계 동아시아 평화 대한 일본 의지 가늠 하다 시금석 이다
# 일본 잘 못 되다 역사 미화 그 근거 권리 주장 하다 하다 한일 간의 우호 관계 결코 바로 설 수가 없다 일본 이 들 문제 집착 하다 하다 우리 한일 간의 미래 동아시아 평화 관 일본 어떻다 수사 믿다 수가 없다 것 이다 어떻다 경제 적 이해관계 문화 적 교류 이 벽 녹이다 못 하다 것 이다
# ...

# %%
with open("NaverMovie.nlp", 'w', encoding='utf-8') as fp:
  fp.write("\n".join(result))

# %%
# !pip install gensim==4.3.0

# %%
from gensim.models.word2vec import LineSentence

mData = LineSentence("NaverMovie.nlp")
mModel = Word2Vec(mData, size=200, window=10, hs=1, min_count=2, sg=1)
mModel.save("NaverMovie.model")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-c9c9f5e222fe> in <cell line: 0>()
#       2
#       3 mData = LineSentence("NaverMovie.nlp")
# ----> 4 mModel = Word2Vec(mData, size=200, window=10, hs=1, min_count=2, sg=1)
#       5 mModel.save("NaverMovie.model")
#
# TypeError: Word2Vec.__init__() got an unexpected keyword argument 'size'
